# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv ('https://gist.githubusercontent.com/tiangechen/b68782efa49a16edaf07dc2cdaa855ea/raw/0c794a9717f18b094eabab2cd6a6b9a226903577/movies.csv')

# %%
df.head()
# Out:
#                                  Film    Genre            Lead Studio  \
# 0          Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                     Youth in Revolt   Comedy  The Weinstein Company
# 2  You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                        When in Rome   Comedy                 Disney
# 4               What Happens in Vegas   Comedy                    Fox
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 0                70       1.747542                 64         $41.94   2008
# 1                52       1.090000                 68         $19.62   2010
# 2                35       1.211818                 43         $26.66   2010
# 3                44       0.000000                 15         $43.04   2010
# 4                72       6.267647                 28        $219.37   2008

# %%
df.tail()
# Out:
#                     Film    Genre  Lead Studio  Audience score %  \
# 72   Across the Universe  romance  Independent                84
# 73         A Serious Man    Drama    Universal                64
# 74    A Dangerous Method    Drama  Independent                89
# 75            27 Dresses   Comedy          Fox                71
# 76  (500) Days of Summer   comedy          Fox                81
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 72       0.652603                 54         $29.37   2007
# 73       4.382857                 89         $30.68   2009
# 74       0.448645                 79          $8.97   2011
# 75       5.343622                 40        $160.31   2008
# 76       8.096000                 87         $60.72   2009

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Lead Studio', 'Audience score %', 'Profitability',
#        'Rotten Tomatoes %', 'Worldwide Gross', 'Year'],
#       dtype='object')

# %%
df.describe() #стисла статистика про дані
# Out:
#        Audience score %  Profitability  Rotten Tomatoes %         Year
# count         77.000000      77.000000          77.000000    77.000000
# mean          63.727273       4.599483          46.701299  2009.077922
# std           13.657113       8.031990          26.095001     1.354974
# min           35.000000       0.000000           3.000000  2007.000000
# 25%           52.000000       1.751351          26.000000  2008.000000
# 50%           64.000000       2.642353          45.000000  2009.000000
# 75%           76.000000       5.103117          64.000000  2010.000000
# max           89.000000      66.934000          96.000000  2011.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               77 non-null     object
#  1   Genre              77 non-null     object
#  2   Lead Studio        77 non-null     object
#  3   Audience score %   77 non-null     int64
#  4   Profitability      77 non-null     float64
#  5   Rotten Tomatoes %  77 non-null     int64
#  6   Worldwide Gross    77 non-null     object
#  7   Year               77 non-null     int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
# 4.кількість фільмів всього - 77
df['Film'].unique() # - перелік фільмів
# Out:
# array(['Zack and Miri Make a Porno', 'Youth in Revolt',
#        'You Will Meet a Tall Dark Stranger', 'When in Rome',
#        'What Happens in Vegas', 'Water For Elephants', 'WALL-E',
#        'Waitress', 'Waiting For Forever', "Valentine's Day",
#        "Tyler Perry's Why Did I get Married", 'Twilight: Breaking Dawn',
#        'Twilight', 'The Ugly Truth', 'The Twilight Saga: New Moon',
#        "The Time Traveler's Wife", 'The Proposal',
#        'The Invention of Lying', 'The Heartbreak Kid', 'The Duchess',
#        'The Curious Case of Benjamin Button', 'The Back-up Plan',
#        'Tangled', 'Something Borrowed', "She's Out of My League",
#        'Sex and the City Two', 'Sex and the City 2', 'Sex and the City',
#        'Remember Me', 'Rachel Getting Married', 'Penelope',
#        'P.S. I Love You', 'Over Her Dead Body', 'Our Family Wedding',
#        'One Day', 'Not Easily Broken', 'No Reservations',
#        "Nick and Norah's Infinite Playlist", "New Year's Eve",
# ...

# %%
df['Year'].value_counts()
#5. кількість фільмів для кожного року:
# Out:
# 2008    20
# 2010    20
# 2011    14
# 2009    12
# 2007    11
# Name: Year, dtype: int64

# %%
df.sort_values('Profitability')
#6. перші 5 записів - 5 найменш прибуткових фільмів
#останні 5 записів - 5 найбільш прибуткових фільмів
# Out:
#                                   Film    Genre  Lead Studio  \
# 3                         When in Rome   Comedy       Disney
# 33                  Our Family Wedding   Comedy  Independent
# 57                           Jane Eyre  Romance    Universal
# 8                  Waiting For Forever  Romance  Independent
# 42      Miss Pettigrew Lives for a Day   Comedy  Independent
# ..                                 ...      ...          ...
# 12                            Twilight  Romance       Summit
# 7                             Waitress  Romance  Independent
# 14         The Twilight Saga: New Moon    Drama       Summit
# 60  High School Musical 3: Senior Year   Comedy       Disney
# 68                           Fireproof    Drama  Independent
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 3                 44       0.000000                 15         $43.04   2010
# 33                49       0.000000                 14         $21.37   2010
# ...

# %%
df['Genre'].unique()
#не уніфіковані види жанрів
# Out:
# array(['Romance', 'Comedy', 'Drama', 'Animation', 'Fantasy', 'Romence',
#        'Comdy', 'Action', 'romance', 'comedy'], dtype=object)

# %%
newdf = df.replace ({'Romence':'Romance','romance': 'Romance','Comdy': 'Comedy', 'comedy': 'Comedy'})
#замінені значення і приведені до єдиних типів жанру, помістила у новий датафрейм з метою збереження первинної бази

# %%
newdf['Genre'].unique()
#перевірка
# Out:
# array(['Romance', 'Comedy', 'Drama', 'Animation', 'Fantasy', 'Action'],
#       dtype=object)

# %%
newdf['max_rank'] = newdf['Audience score %'].rank(method='min',ascending=False)
#присвоїти ранг по полю від найбільшого, по якому відберемо топ 10 фільмів

# %%
newdf2 = newdf[newdf['max_rank']< 11]

# %%
newdf2.sort_values('Audience score %')
# Out:
#                                    Film      Genre            Lead Studio  \
# 20  The Curious Case of Benjamin Button    Fantasy           Warner Bros.
# 27                     Sex and the City     Comedy           Warner Bros.
# 76                 (500) Days of Summer     Comedy                    Fox
# 12                             Twilight    Romance                 Summit
# 31                      P.S. I Love You    Romance            Independent
# 54                           Knocked Up     Comedy              Universal
# 39                 My Week with Marilyn      Drama  The Weinstein Company
# 43                    Midnight in Paris    Romance                   Sony
# 72                  Across the Universe    Romance            Independent
# 22                              Tangled  Animation                 Disney
# 6                                WALL-E  Animation                 Disney
# 74                   A Dangerous Method      Drama            Independent
#
# ...

# %%
newdf2[['Film', 'Year','Lead Studio'] ].to_csv('C:/Users/admin/Desktop/навчання/newdf2.csv')
